# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0e8357699fe3d44ff55e50a7f18a5649

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc    = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_desc})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | alghero
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | tornio
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kailua
# Processing Record 13 of Set 1 | xique-xique
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | dalby
# Processing Record 18 of Set 1 | bozeman
# Processing Record 19 of Set 1 | utica
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | labuhan
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | saryozek
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | manono
# Processing Record 32 of Set 1 | eyl
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | san cristobal
# Processing Record 38 of Set 1 | meulaboh
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | karratha
# Processing Record 41 of Set 1 | guadalupe y calvo
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | shebalino
# Processing Record 46 of Set 1 | gravdal
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | novyy urengoy
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 2 | sorland
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | smidovich
# Processing Record 8 of Set 2 | sept-iles
# Processing Record 9 of Set 2 | nouakchott
# Processing Record 10 of Set 2 | san quintin
# Processing Record 11 of Set 2 | sunndalsora
# Processing Record 12 of Set 2 | kavieng
# Processing Record 13 of Set 2 | kourou
# Processing Record 14 of Set 2 | chibombo
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | faya
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | gandorhun
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | belyy yar
# Processing Record 22 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | bouna
# Processing Record 27 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 2 | vershino-darasunskiy
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | rio brilhante
# Processing Record 31 of Set 2 | corralillo
# Processing Record 32 of Set 2 | amahai
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | umm lajj
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | quang ngai
# Processing Record 41 of Set 2 | yar-sale
# Processing Record 42 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | paamiut
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | darab
# Processing Record 46 of Set 2 | peruibe
# Processing Record 47 of Set 2 | parabel
# Processing Record 48 of Set 2 | havre-saint-pierre
# Processing Record 49 of Set 2 | dianalund
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | dong hoi
# Processing Record 2 of Set 3 | kirovskiy
# Processing Record 3 of Set 3 | puerto rondon
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | de aar
# Processing Record 7 of Set 3 | alto araguaia
# Processing Record 8 of Set 3 | camacha
# Processing Record 9 of Set 3 | fernandopolis
# Processing Record 10 of Set 3 | khash
# Processing Record 11 of Set 3 | olga
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | zhigansk
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | kapit
# Processing Record 20 of Set 3 | rosamorada
# Processing Record 21 of Set 3 | ipixuna
# Processing Record 22 of Set 3 | vila franca do campo
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | chunskiy
# Processing Record 25 of Set 3 | pakxan
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | shu
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | krasnoselkup
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | ambulu
# Processing Record 35 of Set 3 | sandy bay
# Processing Record 36 of Set 3 | hundested
# Processing Record 37 of Set 3 | luganville
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | filadelfia
# Processing Record 42 of Set 3 | quelimane
# Processing Record 43 of Set 3 | fortuna
# Processing Record 44 of Set 3 | avera
# Processing Record 45 of Set 3 | romny
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | dudinka
# Processing Record 48 of Set 3 | platanos
# Processing Record 49 of Set 3 | phalombe
# Processing Record 50 of Set 3 | kenai
# Processing Record 1 of Set 4 | dwarka
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | mareeba
# Processing Record 4 of Set 4 | deputatskiy
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | awjilah
# Processing Record 7 of Set 4 | roma
# Processing Record 8 of Set 4 | general roca
# Processing Record 9 of Set 4 | boli
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | springfield
# Processing Record 13 of Set 4 | anastacio
# Processing Record 14 of Set 4 | kysyl-syr
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | piacabucu
# Processing Record 17 of Set 4 | caravelas
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | el retorno
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | laurel
# Processing Record 26 of Set 4 | burica
# City not found. Skipping...
# Processing Record 27 of Set 4 | aykhal
# Processing Record 28 of Set 4 | etchoropo
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | port hardy
# Processing Record 31 of Set 4 | puerto penasco
# Processing Record 32 of Set 4 | dera ghazi khan
# Processing Record 33 of Set 4 | palmeiras de goias
# Processing Record 34 of Set 4 | palmer
# Processing Record 35 of Set 4 | nanakuli
# Processing Record 36 of Set 4 | zhezkazgan
# Processing Record 37 of Set 4 | imeni poliny osipenko
# Processing Record 38 of Set 4 | kalugumalai
# Processing Record 39 of Set 4 | taltal
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | pyay
# Processing Record 42 of Set 4 | luena
# Processing Record 43 of Set 4 | lovozero
# Processing Record 44 of Set 4 | monteagudo
# Processing Record 45 of Set 4 | santa cruz
# Processing Record 46 of Set 4 | alice springs
# Processing Record 47 of Set 4 | chlumec
# Processing Record 48 of Set 4 | vanimo
# Processing Record 49 of Set 4 | the valley
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | bandarbeyla
# Processing Record 2 of Set 5 | maralal
# Processing Record 3 of Set 5 | kokopo
# Processing Record 4 of Set 5 | nikolskoye
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | san andres
# Processing Record 7 of Set 5 | shingu
# Processing Record 8 of Set 5 | te anau
# Processing Record 9 of Set 5 | polkowice
# Processing Record 10 of Set 5 | guarapari
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | wenling
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | novomykolayivka
# Processing Record 16 of Set 5 | port hedland
# Processing Record 17 of Set 5 | flin flon
# Processing Record 18 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 5 | mgachi
# Processing Record 20 of Set 5 | kyra
# Processing Record 21 of Set 5 | salta
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | keelung
# Processing Record 24 of Set 5 | panyutyne
# Processing Record 25 of Set 5 | garowe
# Processing Record 26 of Set 5 | vagur
# Processing Record 27 of Set 5 | yurino
# Processing Record 28 of Set 5 | batemans bay
# Processing Record 29 of Set 5 | chilca
# Processing Record 30 of Set 5 | acapulco
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | iskateley
# Processing Record 35 of Set 5 | oranjemund
# Processing Record 36 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 5 | laguna
# Processing Record 38 of Set 5 | bilibino
# Processing Record 39 of Set 5 | ranong
# Processing Record 40 of Set 5 | pizarro
# Processing Record 41 of Set 5 | redlands
# Processing Record 42 of Set 5 | thompson
# Processing Record 43 of Set 5 | algodones
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | niscemi
# Processing Record 46 of Set 5 | nadym
# Processing Record 47 of Set 5 | omsukchan
# Processing Record 48 of Set 5 | shenjiamen
# Processing Record 49 of Set 5 | berdigestyakh
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | bafoulabe
# Processing Record 2 of Set 6 | halmeu
# Processing Record 3 of Set 6 | provideniya
# Processing Record 4 of Set 6 | manakara
# Processing Record 5 of Set 6 | salinopolis
# Processing Record 6 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 6 | kandrian
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | guerrero negro
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | banjarmasin
# Processing Record 12 of Set 6 | melfi
# Processing Record 13 of Set 6 | minas de barroteran
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 6 | port hueneme
# Processing Record 17 of Set 6 | bocaiuva
# Processing Record 18 of Set 6 | moundou
# Processing Record 19 of Set 6 | esik
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | sibolga
# Processing Record 22 of Set 6 | kenora
# Processing Record 23 of Set 6 | tambura
# Processing Record 24 of Set 6 | zaltan
# Processing Record 25 of Set 6 | sandakan
# Processing Record 26 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 6 | torbay
# Processing Record 28 of Set 6 | okhotsk
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | ulaangom
# Processing Record 31 of Set 6 | kudahuvadhoo
# Processing Record 32 of Set 6 | flums
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | luanda
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | boden
# Processing Record 37 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 6 | griffith
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | grand baie
# Processing Record 41 of Set 6 | lasa
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | pacific grove
# Processing Record 44 of Set 6 | norman wells
# Processing Record 45 of Set 6 | guasdualito
# Processing Record 46 of Set 6 | vao
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | lakes entrance
# Processing Record 49 of Set 6 | kathmandu
# Processing Record 50 of Set 6 | auki
# Processing Record 1 of Set 7 | lac du bonnet
# Processing Record 2 of Set 7 | dunedin
# Processing Record 3 of Set 7 | korgen
# Processing Record 4 of Set 7 | seydi
# Processing Record 5 of Set 7 | mathathane
# Processing Record 6 of Set 7 | tambovka
# Processing Record 7 of Set 7 | tete
# Processing Record 8 of Set 7 | north bend
# Processing Record 9 of Set 7 | saint-augustin
# Processing Record 10 of Set 7 | yarada
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | coquimbo
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | serenje
# Processing Record 15 of Set 7 | veinticinco de mayo
# Processing Record 16 of Set 7 | vesyegonsk
# Processing Record 17 of Set 7 | teya
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | hirara
# Processing Record 20 of Set 7 | pribelskiy
# City not found. Skipping...
# Processing Record 21 of Set 7 | antu
# Processing Record 22 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 7 | tuatapere
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | alunis
# Processing Record 26 of Set 7 | falmouth
# Processing Record 27 of Set 7 | margate
# Processing Record 28 of Set 7 | yabrud
# Processing Record 29 of Set 7 | raga
# Processing Record 30 of Set 7 | karaton
# Processing Record 31 of Set 7 | maraba
# Processing Record 32 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 7 | rudsar
# Processing Record 34 of Set 7 | baoqing
# Processing Record 35 of Set 7 | kharitonovo
# Processing Record 36 of Set 7 | realeza
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | asyut
# Processing Record 39 of Set 7 | lingao
# Processing Record 40 of Set 7 | impfondo
# Processing Record 41 of Set 7 | buchanan
# Processing Record 42 of Set 7 | mount gambier
# Processing Record 43 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 7 | muravlenko
# Processing Record 45 of Set 7 | khanpur
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | aykino
# Processing Record 48 of Set 7 | yuli
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | colares
# Processing Record 1 of Set 8 | saint anthony
# Processing Record 2 of Set 8 | kodino
# Processing Record 3 of Set 8 | puerto suarez
# Processing Record 4 of Set 8 | kodinsk
# Processing Record 5 of Set 8 | aksarka
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | porto novo
# Processing Record 8 of Set 8 | balvi
# Processing Record 9 of Set 8 | denpasar
# Processing Record 10 of Set 8 | esperance
# Processing Record 11 of Set 8 | sungairaya
# Processing Record 12 of Set 8 | ler
# Processing Record 13 of Set 8 | markapur
# Processing Record 14 of Set 8 | winsum
# Processing Record 15 of Set 8 | toma
# Processing Record 16 of Set 8 | axim
# Processing Record 17 of Set 8 | prainha
# Processing Record 18 of Set 8 | sao gabriel da cachoeira
# Processing Record 19 of Set 8 | quatre cocos
# Processing Record 20 of Set 8 | vuktyl
# Processing Record 21 of Set 8 | opuwo
# Processing Record 22 of Set 8 | plaster rock
# Processing Record 23 of Set 8 | clyde river
# Processing Record 24 of Set 8 | bayir
# Processing Record 25 of Set 8 | dubrovytsya
# Processing Record 26 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 8 | churapcha
# Processing Record 28 of Set 8 | tutoia
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | saint-francois
# Processing Record 33 of Set 8 | maceio
# Processing Record 34 of Set 8 | lashio
# Processing Record 35 of Set 8 | santa fe
# Processing Record 36 of Set 8 | terrace
# Processing Record 37 of Set 8 | xining
# Processing Record 38 of Set 8 | gamba
# Processing Record 39 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 8 | merke
# Processing Record 42 of Set 8 | san fernando
# Processing Record 43 of Set 8 | port augusta
# Processing Record 44 of Set 8 | inirida
# Processing Record 45 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 8 | vila
# Processing Record 47 of Set 8 | lewisville
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | turukhansk
# Processing Record 50 of Set 8 | malpe
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | ahipara
# Processing Record 3 of Set 9 | simao
# Processing Record 4 of Set 9 | karasjok
# Processing Record 5 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 9 | half moon bay
# Processing Record 7 of Set 9 | saint-joseph
# Processing Record 8 of Set 9 | qinhuangdao
# Processing Record 9 of Set 9 | orlik
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | padang
# Processing Record 12 of Set 9 | monroe
# Processing Record 13 of Set 9 | ureki
# Processing Record 14 of Set 9 | taruma
# Processing Record 15 of Set 9 | buin
# Processing Record 16 of Set 9 | conceicao do araguaia
# Processing Record 17 of Set 9 | touros
# Processing Record 18 of Set 9 | jatiroto
# Processing Record 19 of Set 9 | sidi ali
# Processing Record 20 of Set 9 | alyangula
# Processing Record 21 of Set 9 | okakarara
# Processing Record 22 of Set 9 | beloha
# Processing Record 23 of Set 9 | uray
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | port lincoln
# Processing Record 27 of Set 9 | poya
# Processing Record 28 of Set 9 | lower hutt
# Processing Record 29 of Set 9 | grootfontein
# Processing Record 30 of Set 9 | merrill
# Processing Record 31 of Set 9 | derzhavinsk
# Processing Record 32 of Set 9 | pafos
# Processing Record 33 of Set 9 | boa vista
# Processing Record 34 of Set 9 | villa rica
# Processing Record 35 of Set 9 | huancavelica
# Processing Record 36 of Set 9 | situbondo
# Processing Record 37 of Set 9 | skibbereen
# Processing Record 38 of Set 9 | mitu
# Processing Record 39 of Set 9 | mancheral
# Processing Record 40 of Set 9 | cortez
# Processing Record 41 of Set 9 | gat
# Processing Record 42 of Set 9 | kangaba
# Processing Record 43 of Set 9 | dzerzhinskoye
# Processing Record 44 of Set 9 | ivajlovgrad
# City not found. Skipping...
# Processing Record 45 of Set 9 | ocean city
# Processing Record 46 of Set 9 | baykit
# Processing Record 47 of Set 9 | uglekamensk
# Processing Record 48 of Set 9 | duz
# City not found. Skipping...
# Processing Record 49 of Set 9 | alofi
# Processing Record 50 of Set 9 | humaita
# Processing Record 1 of Set 10 | sujiatun
# Processing Record 2 of Set 10 | qaqortoq
# Processing Record 3 of Set 10 | yali
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | binga
# Processing Record 6 of Set 10 | carutapera
# Processing Record 7 of Set 10 | ous
# Processing Record 8 of Set 10 | magistralnyy
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | natal
# Processing Record 11 of Set 10 | banda aceh
# Processing Record 12 of Set 10 | smithers
# Processing Record 13 of Set 10 | naruto
# Processing Record 14 of Set 10 | ilhabela
# Processing Record 15 of Set 10 | marystown
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | sciacca
# Processing Record 18 of Set 10 | cockburn town
# Processing Record 19 of Set 10 | shahr-e kord
# Processing Record 20 of Set 10 | vung tau
# Processing Record 21 of Set 10 | erdenet
# Processing Record 22 of Set 10 | at-bashi
# Processing Record 23 of Set 10 | ostrovnoy
# Processing Record 24 of Set 10 | felanitx
# Processing Record 25 of Set 10 | seoul
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 29 of Set 10 | feldbach
# Processing Record 30 of Set 10 | cap-aux-meules
# Processing Record 31 of Set 10 | dhidhdhoo
# Processing Record 32 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 10 | choma
# Processing Record 34 of Set 10 | sayhat
# Processing Record 35 of Set 10 | muroto
# Processing Record 36 of Set 10 | xichang
# Processing Record 37 of Set 10 | cairns
# Processing Record 38 of Set 10 | sisimiut
# Processing Record 39 of Set 10 | havoysund
# Processing Record 40 of Set 10 | bekwai
# Processing Record 41 of Set 10 | along
# Processing Record 42 of Set 10 | marawi
# Processing Record 43 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 10 | yaan
# Processing Record 45 of Set 10 | sao filipe
# Processing Record 46 of Set 10 | vila do maio
# Processing Record 47 of Set 10 | maardu
# Processing Record 48 of Set 10 | leshan
# Processing Record 49 of Set 10 | tyrma
# Processing Record 50 of Set 10 | nicoya
# Processing Record 1 of Set 11 | harnosand
# Processing Record 2 of Set 11 | emerald
# Processing Record 3 of Set 11 | puerto escondido
# Processing Record 4 of Set 11 | katsuura
# Processing Record 5 of Set 11 | marsh harbour
# Processing Record 6 of Set 11 | soyo
# Processing Record 7 of Set 11 | chimbote
# Processing Record 8 of Set 11 | sobolevo
# Processing Record 9 of Set 11 | tilichiki
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | west wendover
# Processing Record 12 of Set 11 | namie
# Processing Record 13 of Set 11 | lorengau
# Processing Record 14 of Set 11 | gisborne
# Processing Record 15 of Set 11 | alugan
# Processing Record 16 of Set 11 | cururupu
# Processing Record 17 of Set 11 | college
# Processing Record 18 of Set 11 | san patricio
# Processing Record 19 of Set 11 | nikolayevsk-na-amure
# Processing Record 20 of Set 11 | unai
# Processing Record 21 of Set 11 | suntar
# Processing Record 22 of Set 11 | fountain
# Processing Record 23 of Set 11 | vasto
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | novyy yarychiv
# Processing Record 26 of Set 11 | puerto del rosario
# Processing Record 27 of Set 11 | uige
# Processing Record 28 of Set 11 | mtambile
# Processing Record 29 of Set 11 | riyadh
# Processing Record 30 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 11 | kribi
# Processing Record 32 of Set 11 | ust-omchug
# Processing Record 33 of Set 11 | poyarkovo
# Processing Record 34 of Set 11 | altenholz
# Processing Record 35 of Set 11 | marquette
# Processing Record 36 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 11 | custodia
# Processing Record 38 of Set 11 | raypur
# Processing Record 39 of Set 11 | asau
# Processing Record 40 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | plettenberg bay
# Processing Record 43 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 44 of Set 11 | kuching
# Processing Record 45 of Set 11 | srednekolymsk
# Processing Record 46 of Set 11 | ati
# Processing Record 47 of Set 11 | vacaresti
# Processing Record 48 of Set 11 | udachnyy
# Processing Record 49 of Set 11 | qeshm
# Processing Record 50 of Set 11 | tahlequah
# Processing Record 1 of Set 12 | korla
# Processing Record 2 of Set 12 | ovalle
# Processing Record 3 of Set 12 | gazojak
# Processing Record 4 of Set 12 | sosnovo-ozerskoye
# Processing Record 5 of Set 12 | athboy
# Processing Record 6 of Set 12 | mayumba
# Processing Record 7 of Set 12 | la rioja
# Processing Record 8 of Set 12 | la antigua
# Processing Record 9 of Set 12 | kupang
# Processing Record 10 of Set 12 | mana
# Processing Record 11 of Set 12 | mae hong son
# Processing Record 12 of Set 12 | perene
# Processing Record 13 of Set 12 | fray bentos
# Processing Record 14 of Set 12 | bonthe
# Processing Record 15 of Set 12 | kitimat
# Processing Record 16 of Set 12 | saint charles
# Processing Record 17 of Set 12 | svolvaer
# Processing Record 18 of Set 12 | fairhope
# Processing Record 19 of Set 12 | ozinki
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | beyneu
# Processing Record 22 of Set 12 | lisala
# Processing Record 23 of Set 12 | oskarshamn
# Processing Record 24 of Set 12 | ojinaga
# Processing Record 25 of Set 12 | bayji
# Processing Record 26 of Set 12 | coihaique
# Processing Record 27 of Set 12 | rorvik
# Processing Record 28 of Set 12 | ambilobe
# Processing Record 29 of Set 12 | sakaraha
# Processing Record 30 of Set 12 | tazovskiy
# Processing Record 31 of Set 12 | pakxe
# Processing Record 32 of Set 12 | kismayo
# Processing Record 33 of Set 12 | uvat
# Processing Record 34 of Set 12 | mecca
# Processing Record 35 of Set 12 | verkhnetulomskiy
# Processing Record 36 of Set 12 | zhangye
# Processing Record 37 of Set 12 | rio gallegos
# Processing Record 38 of Set 12 | finnsnes
# Processing Record 39 of Set 12 | condado
# Processing Record 40 of Set 12 | jinji
# Processing Record 41 of Set 12 | koroni
# Processing Record 42 of Set 12 | santo domingo
# Processing Record 43 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 12 | teahupoo
# Processing Record 45 of Set 12 | jalu
# Processing Record 46 of Set 12 | bamiantong
# Processing Record 47 of Set 12 | kaitangata
# Processing Record 48 of Set 12 | mora
# Processing Record 49 of Set 12 | sukhumi
# Processing Record 50 of Set 12 | vallenar
# Processing Record 1 of Set 13 | myaundzha
# Processing Record 2 of Set 13 | leningradskiy
# Processing Record 3 of Set 13 | lianzhou
# Processing Record 4 of Set 13 | abbeville
# Processing Record 5 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 13 | bako
# Processing Record 7 of Set 13 | montanha
# Processing Record 8 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 13 | jinchang
# Processing Record 10 of Set 13 | canmore
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | latung
# Processing Record 13 of Set 13 | japura
# Processing Record 14 of Set 13 | skibotn
# Processing Record 15 of Set 13 | key west
# Processing Record 16 of Set 13 | bronnoysund
# Processing Record 17 of Set 13 | ouegoa
# Processing Record 18 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | kholm
# Processing Record 20 of Set 13 | taoudenni
# Processing Record 21 of Set 13 | ixtapa
# Processing Record 22 of Set 13 | copiapo
# Processing Record 23 of Set 13 | isangel
# Processing Record 24 of Set 13 | fairview
# Processing Record 25 of Set 13 | gangawati
# Processing Record 26 of Set 13 | puerto leguizamo
# Processing Record 27 of Set 13 | cam ranh
# Processing Record 28 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 13 | coahuayana
# Processing Record 31 of Set 13 | havelock
# Processing Record 32 of Set 13 | dalvik
# Processing Record 33 of Set 13 | culebra
# Processing Record 34 of Set 13 | shimoni
# Processing Record 35 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 13 | muli
# Processing Record 37 of Set 13 | aksu
# Processing Record 38 of Set 13 | los llanos de aridane
# Processing Record 39 of Set 13 | ukiah
# Processing Record 40 of Set 13 | salinas
# Processing Record 41 of Set 13 | boguchany
# Processing Record 42 of Set 13 | bo rai
# Processing Record 43 of Set 13 | itarema
# Processing Record 44 of Set 13 | lethem
# Processing Record 45 of Set 13 | sao miguel do araguaia
# Processing Record 46 of Set 13 | bohicon
# Processing Record 47 of Set 13 | burlington
# Processing Record 48 of Set 13 | marapanim
# Processing Record 49 of Set 13 | port-gentil
# Processing Record 50 of Set 13 | zhytomyr
# Processing Record 1 of Set 14 | guiratinga
# Processing Record 2 of Set 14 | saldus
# Processing Record 3 of Set 14 | port ellen
# City not found. Skipping...
# Processing Record 4 of Set 14 | hurricane
# Processing Record 5 of Set 14 | poum
# Processing Record 6 of Set 14 | roebourne
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | ust-kulom
# Processing Record 9 of Set 14 | westport
# Processing Record 10 of Set 14 | moindou
# Processing Record 11 of Set 14 | isla vista
# Processing Record 12 of Set 14 | tabory
# Processing Record 13 of Set 14 | nohar
# Processing Record 14 of Set 14 | ponta delgada
# Processing Record 15 of Set 14 | sao joao da barra
# Processing Record 16 of Set 14 | mpika
# Processing Record 17 of Set 14 | torit
# Processing Record 18 of Set 14 | maragogi
# Processing Record 19 of Set 14 | tongliao
# Processing Record 20 of Set 14 | collie
# Processing Record 21 of Set 14 | colac
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | dali
# Processing Record 24 of Set 14 | zambezi
# Processing Record 25 of Set 14 | svetlogorsk
# Processing Record 26 of Set 14 | cordoba
# Processing Record 27 of Set 14 | laiagam
# City not found. Skipping...
# Processing Record 28 of Set 14 | bystrice
# Processing Record 29 of Set 14 | vostok
# Processing Record 30 of Set 14 | igarka
# Processing Record 31 of Set 14 | saint simons
# Processing Record 32 of Set 14 | tateyama
# Processing Record 33 of Set 14 | moree
# Processing Record 34 of Set 14 | high level
# Processing Record 35 of Set 14 | san jose
# Processing Record 36 of Set 14 | konongo
# Processing Record 37 of Set 14 | allende
# Processing Record 38 of Set 14 | road town
# Processing Record 39 of Set 14 | san bartolome de tirajana
# Processing Record 40 of Set 14 | yasothon
# Processing Record 41 of Set 14 | severnoye
# Processing Record 42 of Set 14 | kisanga
# Processing Record 43 of Set 14 | mandurah
# Processing Record 44 of Set 14 | mildura
# Processing Record 45 of Set 14 | viedma
# Processing Record 46 of Set 14 | nuuk
# Processing Record 47 of Set 14 | beira
# Processing Record 48 of Set 14 | pangkalanbuun
# Processing Record 49 of Set 14 | rocky mountain house
# Processing Record 50 of Set 14 | amos
# Processing Record 1 of Set 15 | aljezur
# Processing Record 2 of Set 15 | grand-santi
# Processing Record 3 of Set 15 | honjo
# Processing Record 4 of Set 15 | caraz
# Processing Record 5 of Set 15 | mogzon
# Processing Record 6 of Set 15 | concepcion de buenos aires
# Processing Record 7 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 15 | cartagena
# Processing Record 9 of Set 15 | sri aman
# Processing Record 10 of Set 15 | sechura
# Processing Record 11 of Set 15 | ndele
# Processing Record 12 of Set 15 | kirishi
# Processing Record 13 of Set 15 | mailsi
# Processing Record 14 of Set 15 | bulolo
# Processing Record 15 of Set 15 | bima
# Processing Record 16 of Set 15 | kasane
# Processing Record 17 of Set 15 | nabire
# Processing Record 18 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 15 | hamilton
# Processing Record 20 of Set 15 | bosaso
# Processing Record 21 of Set 15 | zheleznodorozhnyy
# Processing Record 22 of Set 15 | rawlins
# Processing Record 23 of Set 15 | neryungri
# Processing Record 24 of Set 15 | smolenka
# Processing Record 25 of Set 15 | roding
# Processing Record 26 of Set 15 | the pas
# Processing Record 27 of Set 15 | tomatlan
# Processing Record 28 of Set 15 | port moresby
# Processing Record 29 of Set 15 | dongfeng
# Processing Record 30 of Set 15 | wageningen
# Processing Record 31 of Set 15 | shelburne
# Processing Record 32 of Set 15 | kushima
# Processing Record 33 of Set 15 | sarangani
# Processing Record 34 of Set 15 | biskamzha
# Processing Record 35 of Set 15 | cesvaine
# Processing Record 36 of Set 15 | huarmey
# Processing Record 37 of Set 15 | ondo
# Processing Record 38 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 39 of Set 15 | presidencia roque saenz pena
# Processing Record 40 of Set 15 | seminole
# Processing Record 41 of Set 15 | menongue
# Processing Record 42 of Set 15 | kaabong
# Processing Record 43 of Set 15 | cedartown
# Processing Record 44 of Set 15 | sao raimundo nonato
# Processing Record 45 of Set 15 | bakau
# Processing Record 46 of Set 15 | ewo
# Processing Record 47 of Set 15 | storozhevaya
# Processing Record 48 of Set 15 | zapolyarnyy
# Processing Record 49 of Set 15 | belmonte
# Processing Record 50 of Set 15 | isoka
# Processing Record 1 of Set 16 | wanning
# Processing Record 2 of Set 16 | ohara
# Processing Record 3 of Set 16 | yialos
# City not found. Skipping...
# Processing Record 4 of Set 16 | odweyne
# Processing Record 5 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 16 | cutler
# Processing Record 7 of Set 16 | mount darwin
# Processing Record 8 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 16 | pombas
# Processing Record 10 of Set 16 | payo
# Processing Record 11 of Set 16 | diamantino
# Processing Record 12 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 16 | henties bay
# Processing Record 14 of Set 16 | basco
# Processing Record 15 of Set 16 | ulladulla
# Processing Record 16 of Set 16 | necochea
# Processing Record 17 of Set 16 | kalmar
# Processing Record 18 of Set 16 | tergnier
# Processing Record 19 of Set 16 | opobo
# City not found. Skipping...
# Processing Record 20 of Set 16 | ahuimanu
# Processing Record 21 of Set 16 | hendijan
# City not found. Skipping...
# Processing Record 22 of Set 16 | sagamihara
# Processing Record 23 of Set 16 | kaeo
# Processing Record 24 of Set 16 | semenyih
# Processing Record 25 of Set 16 | camopi
# Processing Record 26 of Set 16 | anzio
# Processing Record 27 of Set 16 | nishihara
# Processing Record 28 of Set 16 | nizhniy tsasuchey
# Processing Record 29 of Set 16 | ilulissat
# Processing Record 30 of Set 16 | guantanamo
# Processing Record 31 of Set 16 | cockburn harbour
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333    106.05        27           2
# 1  Punta Arenas -53.1500  -70.9167     53.71        82           0
# 2         Kapaa  22.0752 -159.3190     75.18        79           0
# 3       Rikitea -23.1203 -134.9692     77.99        78          99
# 4      Saldanha -33.0117   17.9442     66.18        72           0
# 5        Avarua -21.2078 -159.7750     78.85        94         100
# 6       Alghero  40.5589    8.3181     50.09        66          20
# 7        Castro -24.7911  -50.0119     62.96        91          41
# 8        Tornio  65.8481   24.1466     24.82        72           4
# 9       Mataura -46.1927  168.8643     57.47        61          69
#
#    Wind Speed Country Current Description
# 0       14.41      AU           clear sky
# 1        4.61      CL           clear sky
# 2        6.91      US           clear sky
# 3       11.63      PF          light rain
# 4        9.82      ZA           clear sky
# 5       20.71      CK                haze
# 6        8.05      IT          few clouds
# 7        1.50      BR    scattered clouds
# 8       16.20      FI           clear sky
# 9        8.61      NZ       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
